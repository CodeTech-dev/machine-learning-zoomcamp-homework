# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/workspaces/machine-learning-zoomcamp-homework/01-intro/car_fuel_efficiency_2026.csv')

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
print(len(df))
# Out:
# 10000

# %%
print(df['fuel_type'].nunique())
# Out:
# 3

# %%
print(df.isnull().sum())
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
max_fuel_efficiency_from_asia =  df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
print(f"The maximum fuel efficiency from asia is: {max_fuel_efficiency_from_asia}")
# Out:
# The maximum fuel efficiency from asia is: 41.2

# %%
median_horsepower = df['horsepower'].median()
mode_horsepower = df['horsepower'].mode()[0]
print(median_horsepower)
print(mode_horsepower)
# Out:
# 254.0
# 252.0

# %%
df['horsepower'].fillna(0)
# Out:
# 0       243.0
# 1       272.0
# 2       267.0
# 3       258.0
# 4       304.0
#         ...
# 9995    271.0
# 9996    244.0
# 9997    267.0
# 9998    270.0
# 9999    295.0
# Name: horsepower, Length: 10000, dtype: float64

# %%
median_horsepower = df['horsepower'].median()
print(median_horsepower)
# Out:
# 254.0

# %%
df_asia_cars = df[df['origin'] == 'Asia']

# %%
df_asia_features = df_asia_cars[['vehicle_weight', 'model_year']]

# %%
print(df_asia_features)
# Out:
#       vehicle_weight  model_year
# 2               4240        1996
# 6               4310        1992
# 8               4230        1997
# 10              4420        1978
# 15              3950        2007
# ...              ...         ...
# 9984            4610        2011
# 9987            4530        2004
# 9990            3630        1975
# 9994            4610        1993
# 9996            4370        1993
#
# [2994 rows x 2 columns]

# %%
df_asia_7 = df_asia_features.head(7)

# %%
print(df_asia_7)
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %%
X = df_asia_7.values

# %%
print(X)
# Out:
# [[4240 1996]
#  [4310 1992]
#  [4230 1997]
#  [4420 1978]
#  [3950 2007]
#  [4750 2021]
#  [4450 2019]]

# %%
XTX = X.T.dot(X)

# %%
print(XTX)
# Out:
# [[131950500  60750580]
#  [ 60750580  28041424]]

# %%
XTX_inv =  np.linalg.inv(XTX)

# %%
(XTX_inv)
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
w = XTX_inv.dot(X.T).dot(y)

# %%
print(w)
# Out:
# [0.13644777 0.2327492 ]

# %%
print (w.sum())
# Out:
# 0.36919696904925486
